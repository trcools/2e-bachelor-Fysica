# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.close_figures = True


import rossler_functions as rossler
import rossler_figures as rossler_fig

# %% [markdown]
# ---
# # 3 The Rössler Attractor
# ---

# %% [markdown]
# ## Introduction
#
# The **Rössler system** is a three-dimensional chaotic dynamical system described by the following ordinary differential equations:
#
# $$
# \begin{align}
# \dot{x} &= -y - z \\
# \dot{y} &= x + ay \\
# \dot{z} &= b + z(x - c)
# \end{align}
# $$
#
# where $a$, $b$, and $c$ are positive parameters that control the system's behavior.
#
#
# We will solve the system numerically, visualize the attractor in 2D and 3D, study how the attractor changes as parameters vary and analyze bifurcations and transitions to chaos.

# %% [markdown]
# An interesting aplication I found in [Electrical circuits](https://www.glensstuff.com/rosslerattractor/rossler.htm), where they use the oscilloscope to accomplish the Rössler attractor.

# %% [markdown]
# ---
# ## 3.1. The Rössler Attractor with Default Parameters
# ---

# %% [markdown]
# Let us start with the classic chaotic parameter regime. The most commonly studied case uses:
# - $a = 0.2$
# - $b = 0.2$
# - $c = 5.7$
#
# These parameters are also used on the [wikipedia](https://en.wikipedia.org/wiki/R%C3%B6ssler_attractor) site, they place the system in the chaotic regime producing a good looking visually strange attractor.

# %%
# --- parameters ---
a, b, c, t_min, t_max, dt, initial_condition, initial_conditions = rossler.get_parameters()

# %% [markdown]
# Further in this notebook you may see $h$ instead of $dt$, note that they have the same meaning of the time step.

# %% [markdown]
# #### Eigenvalues and eigenvectors
#
# The stability of each fixed point follows from the eigenvalues of the Jacobian
# $$
# J = \begin{pmatrix}
# 0 & -1 & -1\\
# 1 & a & 0\\
# z & 0 & x-c
# \end{pmatrix}.
# $$
# The characteristic polynomial is
# $$
# -\lambda^3 + \lambda^2(a + x - c) + \lambda\,(ac - ax - 1 - z) + x - c + a z = 0.
# $$
#
# When we substitute an equilibrium point $(x_{eq}, y_{eq}, z_{eq})$ into this cubic equation, we obtain three eigenvalues $\lambda_i$ whose real parts determine the stability behavior of that fixed point. If all eigenvalues have negative real parts ($\Re(\lambda_i) < 0$), the equilibrium is stable and trajectories are attracted toward it. Conversely, if at least one eigenvalue has a positive real part ($\Re(\lambda_i) > 0$), the equilibrium becomes unstable or behaves as a saddle-focus, causing trajectories to be repelled along certain directions. When eigenvalues appear as complex-conjugate pairs, the system exhibits spiral motion around the equilibrium. In particular, a positive real part in such a conjugate pair produces the characteristic saddle-focus spiraling that we observe in the Rössler attractor.
#
# [Mathematical details](https://www.cfm.brown.edu/people/dobrush/am34/Mathematica/ch3/rossler.html)

# %% [markdown]
# The two **equilibria** are given by:

# %%
rossler.print_solutions()
# Out:
# Solution 1:
#  X = c/2 - sqrt(-4*a*b + c**2)/2 Y = (-c + sqrt(-4*a*b + c**2))/(2*a) Z = c/(2*a) - sqrt(-4*a*b + c**2)/(2*a)
#
# Solution 2:
#  X = c/2 + sqrt(-4*a*b + c**2)/2 Y = (-c - sqrt(-4*a*b + c**2))/(2*a) Z = c/(2*a) + sqrt(-4*a*b + c**2)/(2*a)

# %% [markdown]
# The equilibria in explicit form are given by:
#
# $$x = \frac{c \pm \sqrt{c^2 - 4ab}}{2}$$
#
# $$y = -\frac{c \pm \sqrt{c^2 - 4ab}}{2a}$$
#
# $$z = \frac{c \pm \sqrt{c^2 - 4ab}}{2a}$$

# %% [markdown]
# If we plot these trajectories, we can see if there is any kind of attractor present.

# %%
# --- Part 3.1: Basic Visualization ---
rossler_fig.nb_show_attractor(a=a, b=b, c=c, initial_condition=initial_condition, t_min=t_min, t_max=t_max, dt=dt)
# Out:
# ...
# Output()

# %% [markdown]
# The attractor shows detailed structure at all scales, which is typical for a strange attractor. We can see that there is some kind of saddle-focus or in other words an saddle spiral. One on the place where we expect it, but there is also a less trivial saddle-spiral as you can see. The attractor has two distinct spiral regions, resembling a twisted ribbon or "almost closed" loop, this is a so called **Two-lobe structure**. The **$xy$-projection** reveals the primary folding structure, while the **$xz$-projection** shows the vertical extent of the oscillations.

# %% [markdown]
# For better visualization, we examine the attractor from three different 2D projection planes.

# %%
# --- All three 2D projections ---
rossler_fig.nb_show_projections(a=a, b=b, c=c, initial_condition=initial_condition, t_min=t_min, t_max=t_max, dt=dt, skip_first_frac=0.2)
# Out:
# ...
# Output()

# %% [markdown]
# Each projection reveals distinct features of the attractor. The $xy$-plane captures the characteristic spiral structure, while the $xz$-plane displays the vertical oscillations with two distinct lobes. The $yz$-plane shows how the system moves through the $y$ and $z$ coordinates over time.

# %% [markdown]
# ---
# ## 3.2. Time Series Analysis
# ---
# <a id="section_3_2"></a>

# %% [markdown]
# To better understand the dynamics, we examine how each component $x(t)$, $y(t)$, and $z(t)$ evolves in time.
#
# For this analysis, we use the fourth-order Runge-Kutta (RK4) method to numerically integrate the system, which provides accurate solutions with reasonable computational cost.

# %% [markdown]
# Let us first examine what happens when we use the same timestep $h=0.1$ for both methods and compare their time series.

# %%
# Compare Euler and RK4 with the same step size (h=0.1)
rossler_fig.nb_compare_euler_vs_rk4(a=a, b=b, c=c, initial_condition=initial_condition,
                                    t_min=0.0, t_max=20, h_rk4=0.1, h_euler=0.1)
# Out:
# ...
# Output()
# Max |Δx|: 1.970e+01 | Max |Δy|: 2.311e+01 | Max |Δz|: 9.145e+01

# %% [markdown]
# The best time interval to look for yourselve is in the interval $t \in [0,25]$.
#
# We see that this is **not accurate**. In fact, Euler's method will explode if we examine a larger time interval. This indicates that Euler's method is not stable for chaotic systems with sensitive dependence on initial conditions.

# %% [markdown]
# We use the function `find_optimal_euler_step` to find an Euler step size that produces an error comparable to a reference RK4 integration with `h=0.1`. Then we compare Euler and RK4 side-by-side.

# %%
# Find optimal Euler step size for comparable precision vs. RK4 (h=0.1)
h_best, err_best = rossler.find_optimal_euler_step(a=a, b=b, c=c, initial_condition=initial_condition,
                                                   t_min=0.0, t_max=60.0, h_rk4=0.1, h0_euler=0.1, max_halvings=20)
print(f"Optimal Euler step h: {h_best:.6f} \nMax error vs RK4: {err_best:.3e}")
# Out:
# Optimal Euler step h: 0.000195
# Max error vs RK4: 3.246e-01

# %% [markdown]
# Using this optimal step size, we can now compare the trajectories obtained with both methods again.
# The time interval is set for $t \in [0,120]$ to see the perturbation slowly diverge from the original trajectory. To see a more extreme example, you can slide the $t_{max}$ to 500, and you will see that their time series differ with a big amplitude.

# %%
# Compare Euler (with found h_best = 0.000195) and RK4 (h=0.1)
rossler_fig.nb_compare_euler_vs_rk4(a=a, b=b, c=c, initial_condition=initial_condition,
                                    t_min=0.0, t_max=120.0, h_rk4=0.1, h_euler=h_best)
# Out:
# ...
# Output()
# Max |Δx|: 2.431e+00 | Max |Δy|: 2.146e+00 | Max |Δz|: 7.560e+00

# %% [markdown]
# It is worth noting that the accuracy of these numerical methods is essentially limited for longer integration times due to the chaotic nature of the system. This limitation refers to the known [butterfly effect](https://en.wikipedia.org/wiki/Butterfly_effect), where small numerical errors grow exponentially over time, eventually dominating the solution.

# %% [markdown]
# Having compared both numerical methods, we now examine the temporal evolution of the system through time series plots.

# %%
rossler_fig.nb_time_series(a=a, b=b, c=c, initial_condition=initial_condition, t_min=30, t_max=300, dt=dt)
# Out:
# ...
# Output()

# %% [markdown]
# The signals never repeat exactly, they are chaotic. Despite their apparent randomness, $x(t)$, $y(t)$, and $z(t)$ remain bounded within the attractor region. The time series exhibit oscillations at multiple frequencies, resembling noise but following deterministic rules. Two trajectories starting very close together diverge exponentially, illustrating the system's **sensitivity to initial conditions**, as demonstrated in the figure below.

# %% [markdown]
# The time interval is set for $t \in [25,250]$ to see the perturbation slowly diverge from the original trajectory. If youo want to see a more extreme example, you can slide the $t_{max}$ to 500 to see the extremum like we did when we compared Euler's method to the Rung-Kutta method.

# %%
rossler_fig.nb_butterfly_effect(a=a, b=b, c=5.7, initial_condition=initial_condition,
                             delta=1e-6, t_min=25, t_max=250, dt=dt)
# Out:
# ...
# Output()

# %%
rossler_fig.nb_plot_sensitivity(c=5.7, t_min=t_min, t_max=t_max, dt=dt, delta=1e-6)
# Out:
# ...
# Output()

# %% [markdown]
# > The limit cycle is orbitally stable if the first Lyapunov coefficient $\alpha$ is negative, and if $\lambda > 0$. [Source](https://en.wikipedia.org/wiki/Hopf_bifurcation#Supercritical_and_subcritical_Hopf_bifurcations)
#
# **Note:** The source above specifically addresses Hopf bifurcations in 2D systems, which differ from the chaos characterization in 3D systems like the Rössler attractor.
#
# >Perron's counterexample shows that a negative largest Lyapunov exponent does not in general indicate stability, and that a positive largest Lyapunov exponent does not, in general, indicate chaos. [Source](https://en.wikipedia.org/wiki/Lyapunov_exponent#Perron_effects_of_largest_Lyapunov_exponent_sign_inversion)
#
# **Note:** While Perron's counterexample presents theoretical limitations, it applies primarily to specific non-autonomous systems. For autonomous systems like the Rössler attractor, a positive largest Lyapunov exponent remains a reliable indicator of chaos.
#
# >If one Lyapunov exponent is larger then zero the nearby trajectories diverge exponentially hence they are chaotic. If the largest Lyapunov exponent is zero one is usually faced with periodic motion. In the case of a largest Lyapunov exponent smaller then zero convergence to a fixed point is expected. More information's about Lyapunov exponents and nonlinear dynamical systems can be found in many textbooks, see for example: E. Ott "Chaos is Dynamical Systems", Cambridge. [Source](https://www.boost.org/doc/libs/latest/libs/numeric/odeint/doc/html/boost_numeric_odeint/tutorial/chaotic_systems_and_lyapunov_exponents.html)
#
# **Note:** This source confirms that for autonomous dynamical systems,
# the sign of the largest Lyapunov exponent is a reliable diagnostic tool. Positive indicates chaos,
# zero indicates periodic behavior, and negative indicates convergence to a stable fixed point.
# This criterion is applicable to the Rössler system.

# %%
rossler.lyapunov_exponent_estimate(a=a, b=b, c=c, initial_condition=initial_condition)
# Out:
# Largest Lyapunov exponent ≈ 0.07020507456911212

# %% [markdown]
# The largest Lypunov exponent $\approx 0.07$, which indicates chaotic behavior.

# %% [markdown]
# The figure above illustrates this exponential divergence by tracking the distance between two initially nearby trajectories. The upper panel shows the distance on a linear scale, while the lower panel uses a logarithmic scale, revealing the approximately exponential growth characteristic of chaotic systems. These plots confirm that the Rössler system exhibits chaotic behavior with high sensitivity to initial conditions.

# %% [markdown]
# ---
# ## 3.3 Effect of Initial Conditions
# ---

# %% [markdown]
# We will verify that different initial conditions converge to the same attractor.

# %%
# --- Part 3.3: Compare Different Initial Conditions ---
_ = rossler_fig.nb_compare_initial_conditions(a=a, b=b, c=c,
                                      initial_conditions=initial_conditions,
                                      t_min=t_min, t_max=t_max, dt=dt)

# %% [markdown]
# All trajectories converge to the **same attractor**, regardless of their initial conditions. The figure displays this in three 2D projection planes: the $xy$-plane reveals the spiral structure where all four trajectories overlap, the $xz$-plane shows the vertical extent of the attractor, and the $yz$-plane illustrates the system's motion in that coordinate space. This convergence illustrates an important property of attractors. They are invariant sets that capture the long-term behavior of dynamical systems.

# %% [markdown]
# ---
# # 3.4 Determing chaos in 2 different ways
# ---

# %% [markdown]
# The butterfly effect demonstrated in [section 3.2](#section_3_2) is one method to characterize chaos through exponential divergence of nearby trajectories. Another approach is the **return map**, which reveals the underlying structure of chaotic dynamics.

# %% [markdown]
# The Rössler attractor exhibits a characteristic return map from the local maxima of $z(t)$.

# %%
rossler_fig.nb_return_map_and_cobweb(a=a, b=b, c=5.7, initial_condition=initial_condition,
                                 t_min=t_min, t_max=2000, dt=dt,
                                 skip_first_maxima=5, cobweb_skip_first=50, n_iter=15)

# %% [markdown]
# The figures above show the return map analysis of the Rössler attractor. The left panel displays
# the time series of $z(t)$ with marked local maxima, illustrating the system's oscillatory behavior.
#
# The right panel shows the **return map**, with each successive maximum $z_{n+1}$ plotted against the
# previous maximum $z_n$. For a chaotic system, this map exhibits a characteristic curved structure
# rather than discrete points as would appear for periodic orbits instead.
#
# The same panel also includes an optional **cobweb diagram** overlay (which can be toggled on or off)
# that visualizes how iterations evolve on the return map, demonstrating the sensitive dependence and
# complex dynamics inherent to chaos.

# %% [markdown]
# ---
# # 3.5 Exploring the Effect of Parameter $c$
# ---

# %% [markdown]
# The parameter $c$ appears in the third equation and influences the $z$-component dynamics. By varying $c$, we can observe how the attractor shape and dynamics change, and eventually witness a transition from periodic to chaotic behavior.

# %%
_ = rossler_fig.nb_parameter_sweep(c_values=[4, 6, 8.5, 8.7, 9, 12], a=0.1, b=0.1, initial_condition=initial_condition,
                           t_min=t_min, t_max=200, dt=dt)

# %% [markdown]
# As we increase the parameter $c$ while keeping $a = b = 0.1$, the Rössler system undergoes a remarkable transformation. It gradually transitions from simple, predictable behavior to chaos. This transition follows a specific pattern called a **[period-doubling bifurcation](https://en.wikipedia.org/wiki/Period-doubling_bifurcation)**, which appears in many natural systems.
#
#
# At $c = 4$, the system exhibits a simple repeating pattern known as a **period-1 orbit**. The trajectory loops once and then repeats this same path indefinitely. When $c$ increases to 6, this stable pattern becomes unstable and splits into a **period-2 orbit**, where the trajectory now loops twice before the pattern repeats.
#
# As $c$ increases to 8.5, we observe a **period-4 orbit** the pattern becomes more complex with four distinct loops. At $c = 8.7$, the doubling continues to produce a **period-8 orbit**, with eight loops creating an increasingly intricate structure.
#
# This doubling process accelerates rapidly, a fundamental characteristic of the [**Feigenbaum route to chaos**](https://en.wikipedia.org/wiki/Feigenbaum_constants). At $c = 9$, the system reaches a critical point where the periodic pattern disappears entirely and the system becomes **chaotic**. The trajectory no longer follows any repeating pattern; instead, it moves unpredictably through phase space. Crucially, two trajectories that start very close together will separate exponentially from each other.
#
# Notably, chaos does not persist indefinitely. At $c = 12$, periodic behavior returns in the form of a **period-3 orbit**, creating what is known as a **periodic window**. This phenomenon demonstrates (according to [Sharkovskii's theorem](https://en.wikipedia.org/wiki/Sharkovskii%27s_theorem)) that periodic orbits can coexist within chaotic regions. This intricate interplay between order and chaos, with periodic windows embedded in chaotic landscapes, is a characteristic feature of nonlinear dynamical systems.

# %% [markdown]
# ---
# ## 3.6 Bifurcation Diagram
# ---

# %% [markdown]
# A bifurcation diagram shows how the long-term behavior of the system changes as a parameter varies. We will plot the local maxima of $x(t)$ as a function of different parameters. We will examine this behavior as we vary both $c$ and $b$.

# %% [markdown]
# Note: This code needs $\approx$ 10 minutes to run, so I implemented a figure of the outcome when this code ran earlier.

# %%
# --- Part 3.5: Bifurcation Diagram ---
fig = rossler_fig.nb_bifurcation_vs_c(a=a, b=b, c_min=0.5, c_max=45, n=1000,
                                   ic=initial_condition, t_min=0, t_max=200, h=0.01)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 2
#       1 # --- Part 3.5: Bifurcation Diagram ---
# ----> 2 fig = rossler_fig.nb_bifurcation_vs_c(a=a, b=b, c_min=0.5, c_max=45, n=1000,
#       3                                    ic=initial_condition, t_min=0, t_max=200, h=0.01)
#
# File ~/Documents/VSC_macbook_tristan/Biophysics/Examen/Exam-part-3/rossler_figures.py:1029, in nb_bifurcation_vs_c(a, b, c_min, c_max, n, ic, t_min, t_max, h)
#    1026 def nb_bifurcation_vs_c(a=0.2, b=0.2, c_min=0.0, c_max=18.0, n=400,
#    1027                         ic=initial_condition, t_min=0.0, t_max=200.0, h=0.01):
#    1028     c_values = np.linspace(c_min, c_max, n)
# -> 1029     return plot_bifurcation("c", c_values, a=a, b=b, c=0.0, ic=ic,
#    1030                            t_min=t_min, t_max=t_max, h=h, skip_frac=0.5)
#
# ...

# %% [markdown]
# ![bif-diag-c.png](attachment:bif-diag-c.png)

# %% [markdown]
# At low $c$ values, we observe few points on the diagram, indicating simple periodic orbits with stable limit cycles. As $c$ increases to intermediate values, a thicker cloud of points emerges, characterizing chaotic behavior with a continuous range of maxima; here the strange attractor resides. At higher $c$ values, the structure evolves further, showing periodic windows and transitions between order and chaos. This resembles the classical bifurcation diagram of the logistic map, but for a continuous 3D system.

# %% [markdown]
# Note: This code needs $\approx$ 10 minutes to run, so I implemented a figure of the outcome when this code ran earlier.

# %%
fig = rossler_fig.nb_bifurcation_vs_b(a=a, c=c, b_min=0.01, b_max=2, n=1000,
                                   ic=initial_condition, t_min=0, t_max=200, h=0.01)

# %% [markdown]
# ![bif-diag-b.png](attachment:bif-diag-b.png)

# %% [markdown]
# With $c$ fixed and $b$ varying, we observe the same route to chaos. At small $b$, the diagram shows discrete periodic maxima, while increasing $b$ creates broad chaotic bands interrupted by periodic windows. Parameter $b$ governs the $z$-feedback strength in the system; the diagram reveals how a stronger or weaker $z$-effect pushes the Rössler oscillations between periodic and chaotic regimes.
